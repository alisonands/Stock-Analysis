# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import YearLocator
from matplotlib.ticker import MaxNLocator, MultipleLocator

from warnings import filterwarnings

# %%
filterwarnings("ignore")
sns.set_theme()

# %%
finance_df = pd.read_csv("Financial_stock_data.csv")
auto_df = pd.read_csv("../Automotive/final_auto_stock_data.csv")
tech_df = pd.read_csv("../tech/tech_data.csv")
finance_df
# Out:
#              Date Ticker   Sector         Industry        Open        High  \
# 0      2018-01-02     WD  Finance         Mortgage   47.700001   47.919998
# 1      2018-01-03     WD  Finance         Mortgage   47.230000   47.230000
# 2      2018-01-04     WD  Finance         Mortgage   46.189999   46.810001
# 3      2018-01-05     WD  Finance         Mortgage   46.110001   48.060001
# 4      2018-01-08     WD  Finance         Mortgage   48.160000   48.880001
# ...           ...    ...      ...              ...         ...         ...
# 29012  2023-11-27    COF  Finance  Credit Services  105.699997  106.610001
# 29013  2023-11-28    COF  Finance  Credit Services  106.370003  109.050003
# 29014  2023-11-29    COF  Finance  Credit Services  109.180000  111.559998
# 29015  2023-11-30    COF  Finance  Credit Services  110.800003  111.970001
# 29016  2023-12-01    COF  Finance  Credit Services  111.339996  115.139999
#
#               Low       Close   Volume
# 0       47.259998   47.320000   181300
# 1       46.090000   46.130001   134800
# 2       46.090000   46.099998   140200
# 3       45.349998   47.980000   336900
# 4       47.369999   47.820000   310100
# ...           ...         ...      ...
# 29012  105.430000  106.180000  1556800
# 29013  106.139999  108.580002  1874500
# 29014  109.180000  110.129997  2087500
# 29015  110.180000  111.660004  2439300
# 29016  111.339996  113.930000  3421900
#
# [29017 rows x 9 columns]

# %%
auto_df
# Out:
#              Date Ticker       Sector                  Industry   Open  \
# 0      2018-01-02   CPRT  Automobiles  Auto & Truck Dealerships  43.52
# 1      2018-01-03   CPRT  Automobiles  Auto & Truck Dealerships  43.63
# 2      2018-01-04   CPRT  Automobiles  Auto & Truck Dealerships  43.50
# 3      2018-01-05   CPRT  Automobiles  Auto & Truck Dealerships  43.77
# 4      2018-01-08   CPRT  Automobiles  Auto & Truck Dealerships  43.59
# ...           ...    ...          ...                       ...    ...
# 28602  2023-11-28   INTC  Automobiles            Semiconductors  43.69
# 28603  2023-11-29   INTC  Automobiles            Semiconductors  44.60
# 28604  2023-11-30   INTC  Automobiles            Semiconductors  44.65
# 28605  2023-12-01   INTC  Automobiles            Semiconductors  44.36
# 28606  2023-12-04   INTC  Automobiles            Semiconductors  43.30
#
#           High     Low  Close      Volume
# 0      43.6700  43.190  43.60    860740.0
# 1      43.8500  43.200  43.39   1152481.0
# 2      43.9500  43.300  43.74   1164240.0
# 3      43.8800  43.030  43.53    922916.0
# 4      43.8600  43.280  43.55   1254075.0
# ...        ...     ...    ...         ...
# 28602  44.3827  43.660  44.23  24548874.0
# 28603  45.3400  44.600  44.94  38982026.0
# 28604  45.0900  44.410  44.70  46262971.0
# 28605  44.3600  42.860  43.74  43928371.0
# 28606  43.3100  41.685  42.35  50417587.0
#
# [28607 rows x 9 columns]

# %%
merge1_df = pd.merge(finance_df, auto_df, on = ["Date", "Ticker", "Sector", "Industry", "Open", "High", "Low", "Close","Volume"], how = "outer")
merged_df = pd.merge(merge1_df, tech_df, on = ["Date", "Ticker", "Sector", "Industry", "Open", "High", "Low", "Close","Volume"], how = "outer")
merged_df
# Out:
#              Date Ticker      Sector  Industry       Open       High  \
# 0      2018-01-02     WD     Finance  Mortgage  47.700001  47.919998
# 1      2018-01-03     WD     Finance  Mortgage  47.230000  47.230000
# 2      2018-01-04     WD     Finance  Mortgage  46.189999  46.810001
# 3      2018-01-05     WD     Finance  Mortgage  46.110001  48.060001
# 4      2018-01-08     WD     Finance  Mortgage  48.160000  48.880001
# ...           ...    ...         ...       ...        ...        ...
# 85339  2023-11-28   CTSH  Technology  Infotech  70.700000  71.520000
# 85340  2023-11-29   CTSH  Technology  Infotech  71.600000  71.800000
# 85341  2023-11-30   CTSH  Technology  Infotech  70.390000  70.520000
# 85342  2023-12-01   CTSH  Technology  Infotech  70.230000  70.870000
# 85343  2023-12-04   CTSH  Technology  Infotech  70.400000  71.480000
#
#              Low      Close     Volume
# 0      47.259998  47.320000   181300.0
# 1      46.090000  46.130001   134800.0
# 2      46.090000  46.099998   140200.0
# 3      45.349998  47.980000   336900.0
# 4      47.369999  47.820000   310100.0
# ...          ...        ...        ...
# 85339  70.700000  71.300000  2607377.0
# 85340  69.895000  70.120000  3521683.0
# 85341  69.800000  70.380000  8254394.0
# 85342  70.080000  70.820000  2672566.0
# 85343  70.220000  71.160000  2405138.0
#
# [85344 rows x 9 columns]

# %% [markdown]
# # **Overall Performance**

# %%
ls1 = []
ls2 = []
ls3 = []
ticker = []
sector = []
industry = []
analysis_df = {}
for symbols in merged_df["Ticker"].unique():
    # Find the dictionary with the earliest date
    con_df = merged_df.loc[merged_df["Ticker"] == symbols]

    # Convert the "date" column to datetime
    con_df["Date"] = pd.to_datetime(con_df["Date"])

    # Find the row with the earliest date
    earliest_date_row = con_df.loc[con_df["Date"].idxmin(), "Open"]
    latest_date_row = con_df.loc[con_df["Date"].idxmax(), "Close"]
    percent_change_price = ((latest_date_row - earliest_date_row)*100)/earliest_date_row

    ticker.append(symbols)
    sector.append(con_df.loc[con_df["Date"].idxmin(), "Sector"])
    industry.append(con_df.loc[con_df["Date"].idxmax(), "Industry"])
    ls1.append(earliest_date_row)
    ls2.append(latest_date_row)
    ls3.append(percent_change_price)


analysis_df = pd.DataFrame({
    "Ticker" : ticker,
    "Sector" : sector,
    "Industry" : industry,
    "Initial Open" : ls1,
    "Final close" : ls2,
    "Total Change in Percent" : ls3

})
analysis_df
# Out:
#    Ticker       Sector                  Industry  Initial Open  Final close  \
# 0      WD      Finance                  Mortgage     47.700001    89.870003
# 1    PFSI      Finance                  Mortgage     22.350000    79.779999
# 2     LDI      Finance                  Mortgage     14.000000     1.980000
# 3     GHI      Finance                  Mortgage     18.150000    17.040001
# 4    COOP      Finance                  Mortgage     10.320000    62.709999
# 5     AFL      Finance                 Insurance     44.180000    82.610001
# 6     HIG      Finance                 Insurance     56.340000    77.820000
# 7     PRU      Finance                 Insurance    115.169998    97.739998
# 8     ALL      Finance                 Insurance    104.070000   137.679993
# 9     PGR      Finance                 Insurance     56.459999   162.460007
# 10     MS      Finance          Asset Management     52.759998    80.889999
# 11    BLK      Finance          Asset Management    518.780029   756.349976
# 12     GS      Finance          Asset Management    257.769989   348.429993
# 13   TROW      Finance          Asset Management    104.440002   102.449997
# 14    BEN      Finance          Asset Management     43.770000    25.629999
# 15      V      Finance           Credit Services    114.570000   256.450012
# 16     MA      Finance           Credit Services    152.009995   414.359985
# 17    AXP      Finance           Credit Services     99.730003   173.759995
# 18    DFS      Finance           Credit Services     77.239998    95.620003
# 19    COF      Finance           Credit Services    100.080002   113.930000
# 20   CPRT  Automobiles  Auto & Truck Dealerships     43.520000    49.090000
# 21    KMX  Automobiles  Auto & Truck Dealerships     64.260000    68.280000
# 22    PAG  Automobiles  Auto & Truck Dealerships     47.980000   154.490000
# 23    LAD  Automobiles  Auto & Truck Dealerships    113.950000   283.090000
# 24     AN  Automobiles  Auto & Truck Dealerships     51.710000   139.120000
# 25   MBLY  Automobiles                Auto Parts     26.710000    39.720000
# 26   APTV  Automobiles                Auto Parts     84.890000    82.830000
# 27    MGA  Automobiles                Auto Parts     56.790000    56.040000
# 28    LKQ  Automobiles                Auto Parts     41.040000    45.710000
# 29    ALV  Automobiles                Auto Parts    127.510000   105.320000
# 30   TSLA  Automobiles        Auto Manufacturers    312.000000   235.580000
# 31     TM  Automobiles        Auto Manufacturers    127.430000   187.370000
# 32    HMC  Automobiles        Auto Manufacturers     34.310000    30.260000
# 33     GM  Automobiles        Auto Manufacturers     41.240000    33.070000
# 34      F  Automobiles        Auto Manufacturers     12.520000    10.700000
# 35   NVDA  Automobiles            Semiconductors    195.780000   455.100000
# 36    TSM  Automobiles            Semiconductors     40.510000    97.010000
# 37   AVGO  Automobiles            Semiconductors    259.770000   923.970000
# 38    AMD  Automobiles            Semiconductors     10.420000   118.570000
# 39   INTC  Automobiles            Semiconductors     46.380000    42.350000
# 40    CRM   Technology                  Software    102.880000   250.660000
# 41    SAP   Technology                  Software    111.230000   159.270000
# 42   INTU   Technology                  Software    158.220000   570.470000
# 43    NOW   Technology                  Software    131.000000   687.620000
# 44     ZI   Technology                  Software     40.000000    14.710000
# 45   AAPL   Technology                  Consumer    170.160000   189.430000
# 46   MSFT   Technology                  Consumer     86.130000   369.140000
# 47   SONY   Technology                  Consumer     45.440000    85.320000
# 48    LPL   Technology                  Consumer     13.920000     4.800000
# 49    ACN   Technology                  Infotech    153.500000   336.430000
# 50    IBM   Technology                  Infotech    154.500000   161.100000
# 51     FI   Technology                  Infotech    131.960000   130.350000
# 52   INFY   Technology                  Infotech     16.270000    17.690000
# 53   CTSH   Technology                  Infotech     71.160000    71.160000
#
#     Total Change in Percent
# 0                 88.406711
# 1                256.957483
# 2                -85.857143
# 3                 -6.115695
# 4                507.655048
# 5                 86.985061
# 6                 38.125665
# 7                -15.134150
# 8                 32.295564
# 9                187.743552
# 10                53.316910
# 11                45.793965
# 12                35.170892
# 13                -1.905405
# 14               -41.443914
# 15               123.836967
# 16               172.587330
# 17                74.230411
# 18                23.795968
# 19                13.838927
# 20                12.798713
# 21                 6.255836
# 22               221.988328
# 23               148.433523
# 24               169.038871
# 25                48.708349
# 26                -2.426670
# 27                -1.320655
# 28                11.379142
# 29               -17.402557
# 30               -24.493590
# 31                47.037589
# 32               -11.804139
# 33               -19.810863
# 34               -14.536741
# 35               132.454796
# 36               139.471735
# 37               255.687724
# 38              1037.907869
# 39                -8.689090
# 40               143.643079
# 41                43.189787
# 42               260.554924
# 43               424.900763
# 44               -63.225000
# 45                11.324636
# 46               328.584698
# 47                87.764085
# 48               -65.517241
# 49               119.172638
# 50                 4.271845
# 51                -1.220067
# 52                 8.727720
# 53                 0.000000

# %% [markdown]
# # **Best Performers by Sector**

# %%
#idxmax returns the index of the max value
best_performer_df = analysis_df.iloc[analysis_df.groupby("Sector")["Total Change in Percent"].idxmax()].reset_index(drop = True)
best_performer_df
# Out:
#   Ticker       Sector        Industry  Initial Open  Final close  \
# 0    AMD  Automobiles  Semiconductors         10.42   118.570000
# 1   COOP      Finance        Mortgage         10.32    62.709999
# 2    NOW   Technology        Software        131.00   687.620000
#
#    Total Change in Percent
# 0              1037.907869
# 1               507.655048
# 2               424.900763

# %%
top_performers_by_sector = best_performer_df["Ticker"]
ls= []
for ticker in top_performers_by_sector:
    line_df = merged_df.loc[(merged_df["Ticker"] == ticker),["Ticker","Date", "Close"]]
    line_df["Year"] = pd.to_datetime(line_df["Date"]).dt.year
    
    ls.append(line_df)
plot_df = pd.concat(ls, ignore_index = True)
plot_df
# Out:
#      Ticker        Date   Close  Year
# 0       AMD  2018-01-02   10.98  2018
# 1       AMD  2018-01-03   11.55  2018
# 2       AMD  2018-01-04   12.12  2018
# 3       AMD  2018-01-05   11.88  2018
# 4       AMD  2018-01-08   12.28  2018
# ...     ...         ...     ...   ...
# 5958    NOW  2023-11-28  665.24  2023
# 5959    NOW  2023-11-29  678.93  2023
# 5960    NOW  2023-11-30  685.74  2023
# 5961    NOW  2023-12-01  690.79  2023
# 5962    NOW  2023-12-04  687.62  2023
#
# [5963 rows x 4 columns]

# %%
ax=sns.lineplot(data=plot_df, x = "Date", y = "Close", hue = "Ticker")

ax.xaxis.set_major_locator(YearLocator())
# ax.xaxis.set_major_locator(MaxNLocator(base = 2))
# ax.xaxis.set_minor_locator(MultipleLocator(1))

plt.show()

# %% [markdown]
# # **Performance by Year**

# %%
merged_df["Year"] = merged_df["Date"].str.split("-").str[0].str[:4]
ls1 = []
ls2 = []
ls3 = []
ticker = []
sector = []
industry = []
year_ls = []
for year in merged_df["Year"].unique():

    yearly_df = merged_df.loc[merged_df["Year"] == year]

    for symbols in yearly_df["Ticker"].unique():
        # Find the ticker with the earliest date
        con_df = yearly_df.loc[yearly_df["Ticker"] == symbols]

        # Convert the "date" column to datetime
        con_df["Date"] = pd.to_datetime(con_df["Date"])

        # Find the row with the earliest date
        earliest_date_row = con_df.loc[con_df["Date"].idxmin(), "Open"]
        latest_date_row = con_df.loc[con_df["Date"].idxmax(), "Close"]
        percent_change_price = ((latest_date_row - earliest_date_row)*100)/earliest_date_row

        ticker.append(symbols)
        sector.append(con_df.loc[con_df["Date"].idxmin(), "Sector"])
        industry.append(con_df.loc[con_df["Date"].idxmax(), "Industry"])
        ls1.append(earliest_date_row)
        ls2.append(latest_date_row)
        ls3.append(percent_change_price)
        year_ls.append(year)
top_by_year = pd.DataFrame({
    "Ticker" : ticker,
    "Year" : year_ls,
    "Sector" : sector,
    "Industry" : industry,
    "Initial Open" : ls1,
    "Final Close" : ls2,
    "Total Change in Percent" : ls3

})
top_by_year
# Out:
#     Ticker  Year      Sector   Industry  Initial Open  Final Close  \
# 0       WD  2018     Finance   Mortgage     47.700001    43.250000
# 1     PFSI  2018     Finance   Mortgage     22.350000    21.260000
# 2      GHI  2018     Finance   Mortgage     18.150000    16.860001
# 3     COOP  2018     Finance   Mortgage     10.320000    11.670000
# 4      AFL  2018     Finance  Insurance     44.180000    45.560001
# ..     ...   ...         ...        ...           ...          ...
# 310    ACN  2023  Technology   Infotech    269.200000   336.430000
# 311    IBM  2023  Technology   Infotech    141.100000   161.100000
# 312     FI  2023  Technology   Infotech    101.720000   130.350000
# 313   INFY  2023  Technology   Infotech     18.180000    17.690000
# 314   CTSH  2023  Technology   Infotech     57.640000    71.160000
#
#      Total Change in Percent
# 0                  -9.329142
# 1                  -4.876958
# 2                  -7.107433
# 3                  13.081399
# 4                   3.123588
# ..                       ...
# 310                24.973997
# 311                14.174344
# 312                28.145891
# 313                -2.695270
# 314                23.455933
#
# [315 rows x 7 columns]

# %%
perf_by_year = pd.DataFrame(top_by_year.groupby(["Year", "Sector"])["Total Change in Percent"].mean())
perf_by_year
# Out:
#                   Total Change in Percent
# Year Sector
# 2018 Automobiles               -13.393407
#      Finance                   -11.083345
#      Technology                 -5.574842
# 2019 Automobiles                47.608147
#      Finance                    33.834788
#      Technology                 36.438111
# 2020 Automobiles                35.298993
#      Finance                    18.944464
#      Technology                 25.401687
# 2021 Automobiles                33.697632
#      Finance                    24.180602
#      Technology                 26.707273
# 2022 Automobiles               -33.253297
#      Finance                   -13.455324
#      Technology                -32.222795
# 2023 Automobiles                34.696392
#      Finance                    11.664808
#      Technology                 28.314930

# %%
sns.barplot(top_by_year, x="Year", y="Total Change in Percent", hue="Sector").set(title='Performance by Year')
plt.show()

# %% [markdown]
# # **Top Performers by Year**

# %%
grouped_df1 = top_by_year.groupby(["Year"])["Total Change in Percent"].idxmax()
best_by_year = top_by_year.iloc[grouped_df1, :]
best_by_year
# Out:
#     Ticker  Year       Sector            Industry  Initial Open  Final Close  \
# 36     AMD  2018  Automobiles      Semiconductors         10.42    18.460000
# 87     AMD  2019  Automobiles      Semiconductors         18.01    45.860000
# 105   COOP  2020      Finance            Mortgage         12.54    31.030001
# 187      F  2021  Automobiles  Auto Manufacturers          8.81    20.770000
# 232   MBLY  2022  Automobiles          Auto Parts         26.71    35.060000
# 296   NVDA  2023  Automobiles      Semiconductors        148.51   455.100000
#
#      Total Change in Percent
# 36                 77.159309
# 87                154.636313
# 105               147.448172
# 187               135.754824
# 232                31.261700
# 296               206.444011

# %%
sns.barplot(best_by_year, x = "Total Change in Percent", y="Year", orient="h", hue = "Ticker").set(title='Top Performers by Year')
plt.show()

# %% [markdown]
# # **Bottom Performers by Year**

# %%
grouped_df2 = top_by_year.groupby(["Year"])["Total Change in Percent"].idxmin()
worst_by_year = top_by_year.iloc[grouped_df2, :]
worst_by_year
# Out:
#     Ticker  Year       Sector            Industry  Initial Open  Final Close  \
# 27     ALV  2018  Automobiles          Auto Parts        127.51        70.23
# 96     LPL  2019   Technology            Consumer          8.00         6.94
# 145   AAPL  2020   Technology            Consumer        296.24       132.69
# 156    LDI  2021      Finance            Mortgage         14.00         4.80
# 237   TSLA  2022  Automobiles  Auto Manufacturers       1147.75       123.18
# 305     ZI  2023   Technology            Software         30.67        14.71
#
#      Total Change in Percent
# 27                -44.921967
# 96                -13.250000
# 145               -55.208615
# 156               -65.714284
# 237               -89.267698
# 305               -52.037822

# %%
sns.barplot(worst_by_year, x = "Total Change in Percent", y="Year", orient="h", hue = "Ticker").set(title='Bottom Performers by Year')
plt.show()

# %% [markdown]
# # Performance by Sector

# %%
perf_by_sector = pd.DataFrame(top_by_year.groupby(["Sector", "Industry"])["Total Change in Percent"].mean())
perf_by_sector
# Out:
#                                       Total Change in Percent
# Sector      Industry
# Automobiles Auto & Truck Dealerships                19.032649
#             Auto Manufacturers                       9.054450
#             Auto Parts                               5.547878
#             Semiconductors                          33.434000
# Finance     Asset Management                         5.121655
#             Credit Services                         11.782492
#             Insurance                                9.364947
#             Mortgage                                16.738930
# Technology  Consumer                                11.999469
#             Infotech                                 7.324265
#             Software                                20.297237

# %%
plt.figure(figsize=(10, 7))
ax = sns.barplot(top_by_year, x="Sector", y="Total Change in Percent", hue ="Industry")
ax.legend(loc = "best", bbox_to_anchor=(1, 1))
ax.set_title("Performace by Sector")
plt.show()
